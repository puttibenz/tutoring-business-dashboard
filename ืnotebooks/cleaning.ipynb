# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
smp_df = pd.read_csv("../data/smp_courses.csv")
onde_df = pd.read_csv("../data/ondemand_courses.csv")
we_df = pd.read_csv("../data/we_courses.csv")
panya_df = pd.read_csv("../data/panya_courses.csv")
physicsbp_df = pd.read_csv("../data/physicsblueprint_courses.csv")

# %%
df = pd.concat([smp_df, onde_df, we_df, panya_df, physicsbp_df], ignore_index=True)
df.shape
# Out:
# (447, 10)

# %%
print(df['institute_name'].value_counts(normalize=True) * 100)
# Out:
# institute_name
# WE By The Brain      35.570470
# SmartMathPro         28.859060
# Panya Society        15.212528
# OnDemand             10.290828
# Physics Blueprint    10.067114
# Name: proportion, dtype: float64

# %%
df.head()
# Out:
#   institute_name                                        course_name  \
# 0   SmartMathPro  PACK TPAT1 (ครบ 3 พาร์ต) + A-Level คณิต 1 (V.เ...
# 1   SmartMathPro                               พิชิตคณิตพื้นฐาน ม.4
# 2   SmartMathPro                        พิชิตการนับและความน่าจะเป็น
# 3   SmartMathPro                                    พิชิตตรีโกณมิติ
# 4   SmartMathPro             พิชิต TPAT1 (พาร์ตเชื่อมโยง&เชาวน์ไทย)
#
#                                                tutor             subject  \
# 0  พี่ปั้น SmartMathPro, อ.ขลุ่ย, พี่หนู, พี่ฟาร์...          คณิตศาสตร์
# 1                               พี่ปั้น SmartMathPro          คณิตศาสตร์
# 2                               พี่ปั้น SmartMathPro               อื่นๆ
# 3                               พี่ปั้น SmartMathPro               อื่นๆ
# 4                                            อ.ขลุ่ย  ความถนัด/TGAT/TPAT
#
#             course_type   learning_format  total_hours    price  \
# 0          คอร์สแพ็กเกจ  วิดีโอ (ออนไลน์)        661.0  23450.0
# 1  ติวเนื้อหา/เสริมเกรด  วิดีโอ (ออนไลน์)         20.0    790.0
# 2  ติวเนื้อหา/เสริมเกรด  วิดีโอ (ออนไลน์)         24.0   1390.0
# 3  ติวเนื้อหา/เสริมเกรด  วิดีโอ (ออนไลน์)         38.0   1590.0
# 4  ติวเนื้อหา/เสริมเกรด  วิดีโอ (ออนไลน์)         22.0   1190.0
#
#    price_per_hour                                            url
# 0           35.48  https://online.smartmathpro.com/product/c032/
# 1           39.50  https://online.smartmathpro.com/product/f015/
# 2           57.92  https://online.smartmathpro.com/product/f011/
# 3           41.84  https://online.smartmathpro.com/product/f007/
# 4           54.09  https://online.smartmathpro.com/product/c006/

# %%
df.isna().sum()
# Out:
# institute_name      0
# course_name         0
# tutor              68
# subject             0
# course_type         0
# learning_format     0
# total_hours         0
# price               0
# price_per_hour      0
# url                 0
# dtype: int64

# %%
df[df['tutor'].isna()]
# Out:
#     institute_name                                        course_name tutor  \
# 130       OnDemand           Pack จับคู่ UpSkill 2 วิชา (เลข ฟิสิกส์)   NaN
# 158       OnDemand                Davance: คอร์ส TURBO สรุป ไทย+สังคม   NaN
# 163       OnDemand             Pack กลุ่มอะตอม ตารางธาตุ และพันธะเคมี   NaN
# 334  Panya Society        Pack สอบติด คอร์ส คณิตศาสตร์ A-Level + TGAT   NaN
# 335  Panya Society                                 สอวน. เคมีโอลิมปิก   NaN
# ..             ...                                                ...   ...
# 397  Panya Society                          สอวน. คอมพิวเตอร์โอลิมปิก   NaN
# 398  Panya Society  TPAT3 ความถนัดด้านวิทยาศาสตร์ เทคโนโลยี และวิศ...   NaN
# 399  Panya Society                       Pack เพิ่มเกรด ม.4 - ฟิสิกส์   NaN
# 400  Panya Society                Pack FAST เคมี + คณิตศาสตร์ A-Level   NaN
# 401  Panya Society                คณิตศาสตร์ TCAS ติดอาวุธลับ UpScore   NaN
#
#                 subject           course_type        learning_format  \
# 130             ฟิสิกส์          คอร์สแพ็กเกจ  วิดีโอ (ออนไลน์/สาขา)
# 158               อื่นๆ  ติวเนื้อหา/เสริมเกรด  วิดีโอ (ออนไลน์/สาขา)
# 163                เคมี          คอร์สแพ็กเกจ  วิดีโอ (ออนไลน์/สาขา)
# 334          คณิตศาสตร์          คอร์สแพ็กเกจ       วิดีโอ (ออนไลน์)
# 335                เคมี  ติวเนื้อหา/เสริมเกรด       วิดีโอ (ออนไลน์)
# ..                  ...                   ...                    ...
# 397               อื่นๆ  ติวเนื้อหา/เสริมเกรด       วิดีโอ (ออนไลน์)
# 398  ความถนัด/TGAT/TPAT  ติวเนื้อหา/เสริมเกรด       วิดีโอ (ออนไลน์)
# 399             ฟิสิกส์          คอร์สแพ็กเกจ       วิดีโอ (ออนไลน์)
# 400          คณิตศาสตร์          คอร์สแพ็กเกจ       วิดีโอ (ออนไลน์)
# 401          คณิตศาสตร์   ติวสอบ A-Level/TCAS       วิดีโอ (ออนไลน์)
#
#      total_hours   price  price_per_hour  \
# 130         90.0  6900.0           76.67
# 158         74.0  5200.0           70.27
# 163         84.5  4300.0           50.89
# 334        265.0  5490.0           20.72
# 335         45.0  2990.0           66.44
# ..           ...     ...             ...
# 397         60.0  2990.0           49.83
# 398         34.0  2490.0           73.24
# 399         92.0  3490.0           37.93
# 400         24.0  2990.0          124.58
# 401         53.0  2490.0           46.98
#
#                                                    url
# 130  https://shoponline.ondemand.in.th/20024149cv.html
# 158    https://shoponline.ondemand.in.th/20021803.html
# 163  https://shoponline.ondemand.in.th/20014059cv.html
# 334        https://panyasociety.com/course/preview/133
# 335        https://panyasociety.com/course/preview/168
# ..                                                 ...
# 397        https://panyasociety.com/course/preview/167
# 398        https://panyasociety.com/course/preview/124
# 399        https://panyasociety.com/course/preview/169
# 400        https://panyasociety.com/course/preview/154
# 401        https://panyasociety.com/course/preview/111
#
# [68 rows x 10 columns]

# %%
df[(df['institute_name'] == 'OnDemand') & (df['tutor'].isna())]
# Out:
#     institute_name                               course_name tutor  subject  \
# 130       OnDemand  Pack จับคู่ UpSkill 2 วิชา (เลข ฟิสิกส์)   NaN  ฟิสิกส์
# 158       OnDemand       Davance: คอร์ส TURBO สรุป ไทย+สังคม   NaN    อื่นๆ
# 163       OnDemand    Pack กลุ่มอะตอม ตารางธาตุ และพันธะเคมี   NaN     เคมี
#
#               course_type        learning_format  total_hours   price  \
# 130          คอร์สแพ็กเกจ  วิดีโอ (ออนไลน